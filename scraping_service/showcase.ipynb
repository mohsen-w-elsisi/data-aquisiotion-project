# %% [markdown]
# # SOSOM: Smart Online Shopping Optimising Machine
#
# DSAI 103 final project by [Mohsen Elsisi](https://mohsenelsisi.com)

# %% [markdown]
# ## Setting up
# The project contains multiple scrapers which implement the main `Scraper` interface. Each of the different classes handles a different vendor, however they all implement the `scrape` method which allows for maximal polymorphism and extensability.
#
# Let's work with an example product we would like to shop for: Iphone 17 air.

# %%
from pandas import DataFrame

product = "keyboard"

# %% [markdown]
# ## Scraping

# %%
from constants import SERB_API_KEY
from scrapers import EbayScraper

results = EbayScraper(SERB_API_KEY).scrape(product)

results

# %%
from scrapers import JumiaScraper

JumiaScraper().scrape(product)

# %%
from scrapers import NoonScraper
from pandas import DataFrame

listings = NoonScraper().scrape(product)

DataFrame(
    [listing.to_json() for listing in listings],
)
# Out:
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# found stale element
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# Exception in thread Thread-8 (routine):
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/web_driver_management.py", line 71, in routine
#     results = worker.start()
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/web_driver_management.py", line 32, in start
#     result = task.execute(self._driver)
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/web_driver_management.py", line 18, in execute
#     return self._func(driver)
#            ~~~~~~~~~~^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 37, in <lambda>
#     WebDriverTask(url, lambda drv: _ListingLinkScraper(drv).scrape())
#                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 97, in scrape
#     self._construct_listing()
#     ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 101, in _construct_listing
#     self._listing = Listing(
#                     ~~~~~~~^
#         name=self.title,
#         ^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#         review_count=self.review_count,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "<string>", line 13, in __init__
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/listing.py", line 33, in __post_init__
#     _PriceValidator(self.price_type, self.price, self.price_range).validate()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/listing.py", line 67, in validate
#     self._validate_discrete_price()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/listing.py", line 73, in _validate_discrete_price
#     raise ValueError("Price cannot be None for discrete price type.")
# ValueError: Price cannot be None for discrete price type.
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# found stale element
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
# trying <function _ListingLinkScraper.title at 0x7222591c37e0>
# trying <function _ListingLinkScraper.image at 0x7222591c3ce0>
# trying <function _ListingLinkScraper.price at 0x7222591c3920>
# trying <function _ListingLinkScraper.subvendor at 0x7222591c3e20>
# trying <function _ListingLinkScraper.rating at 0x7222591c3a60>
# trying <function _ListingLinkScraper.review_count at 0x7222591c3ba0>
# missing element
#                                                  name  \
# 0   Wired Keyboard K519 USB Multimedia Keyboard , ...
# 1   K568 DARK AVENGER Rainbow MECHANICAL GAMING KE...
# 2   Wired USB keyboard pro office FV-236 for busin...
# 3   Wired Gasket RGB Gaming Keyboard K709 60%, 68 ...
# 4   K688-RGB-BRAGI PRO Wireless Mechanical Gaming ...
# 5   Mechanical Gaming Keyboard Pro , RGB Cool Ligh...
# 6   TGK313 BORA Gaming Mechanical Keyboard with LE...
# 7   Mechanical luminous gaming keyboard , K-880 ra...
# 8   FV-Q8 Wired Gaming Keyboard Esports Light-Emit...
# 9   FV-Q301 Rainbow TKL Mechanical Gaming Keyboard...
# 10  Wired USB keyboard FV-Q515 , 104 key arrangeme...
# 11  Redragon K587 Magic-Wand RGB Mechanical Gaming...
# 12  KG010-KN Wired Mechanical Gaming Keyboard , 10...
# 13  TGK313 BORA Gaming Mechanical Keyboard with LE...
#
#                                                   url  \
# 0   https://www.noon.com/egypt-en/wired-keyboard-k...
# 1   https://www.noon.com/egypt-en/k568-dark-avenge...
# 2   https://www.noon.com/egypt-en/wired-usb-keyboa...
# 3   https://www.noon.com/egypt-en/wired-gasket-rgb...
# 4   https://www.noon.com/egypt-en/k688-rgb-bragi-p...
# 5   https://www.noon.com/egypt-en/mechanical-gamin...
# 6   https://www.noon.com/egypt-en/tgk313-bora-gami...
# 7   https://www.noon.com/egypt-en/mechanical-lumin...
# 8   https://www.noon.com/egypt-en/fv-q8-wired-gami...
# 9   https://www.noon.com/egypt-en/fv-q301-rainbow-...
# 10  https://www.noon.com/egypt-en/wired-usb-keyboa...
# 11  https://www.noon.com/egypt-en/redragon-k587-ma...
# 12  https://www.noon.com/egypt-en/kg010-kn-wired-m...
# 13  https://www.noon.com/egypt-en/tgk313-bora-gami...
#
#                                                 image price_type   price  \
# 0   https://f.nooncdn.com/p/pzsku/ZEB7FC8892C9D1E2...   discrete   190.0
# 1   https://f.nooncdn.com/p/v1564984401/N15598304A...   discrete  1250.0
# 2   https://f.nooncdn.com/p/pzsku/ZEAC10BE559720E7...   discrete   245.0
# 3   https://f.nooncdn.com/p/pnsku/N70153873V/45/_/...   discrete  1999.0
# 4   https://f.nooncdn.com/p/pnsku/N70168678V/45/_/...   discrete  3475.0
# 5   https://f.nooncdn.com/p/pzsku/ZC08E1564595B7D6...   discrete   950.0
# 6   https://f.nooncdn.com/p/pzsku/ZEDC1A208EF1E2F7...   discrete   975.0
# 7   https://f.nooncdn.com/p/pzsku/Z821F688C937E784...   discrete   775.0
# 8   https://f.nooncdn.com/p/pzsku/ZDBBB84A6E7971B7...   discrete   515.0
# 9   https://f.nooncdn.com/p/pzsku/ZC095E3E62AB5767...   discrete   975.0
# 10  https://f.nooncdn.com/p/pzsku/Z5E375BAE9129C49...   discrete  1500.0
# 11  https://f.nooncdn.com/p/v1666686184/N47669218A...   discrete  2555.0
# 12                                                NaN   discrete  1100.0
# 13  https://f.nooncdn.com/p/pzsku/ZB1A285F7DFC5C71...   discrete   875.0
#
#    price_range vendor   subvendor  rating review_count
# 0         None   Noon  PlanetGate     4.3         None
# 1         None   Noon  PlanetGate     4.6         None
# 2         None   Noon  PlanetGate     4.7         None
# 3         None   Noon  PlanetGate     4.7         None
# 4         None   Noon  PlanetGate     5.0         None
# 5         None   Noon  PlanetGate     5.0         None
# 6         None   Noon  PlanetGate     4.6         None
# 7         None   Noon  PlanetGate     4.1         None
# 8         None   Noon  PlanetGate     3.9         None
# 9         None   Noon  PlanetGate     3.9         None
# 10        None   Noon  PlanetGate     5.0         None
# 11        None   Noon  ShiftStore     5.0         None
# 12        None   Noon  PlanetGate     5.0         None
# 13        None   Noon  PlanetGate     4.8         None
