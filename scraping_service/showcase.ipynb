# %% [markdown]
# # SOSOM: Smart Online Shopping Optimising Machine
#
# DSAI 103 final project by [Mohsen Elsisi](https://mohsenelsisi.com)

# %% [markdown]
# ## Setting up
# The project contains multiple scrapers which implement the main `Scraper` interface. Each of the different classes handles a different vendor, however they all implement the `scrape` method which allows for maximal polymorphism and extensability.
#
# Let's work with an example product we would like to shop for: Iphone 17 air.

# %%
from dotenv import load_dotenv
from pandas import DataFrame

from scrapers.read_once_list import ReadOnceList

product = "keyboard"

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Scraping

# %%
from constants import SERB_API_KEY
from scrapers import EbayScraper

results = EbayScraper(SERB_API_KEY).scrape(product)

results
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 from constants import SERB_API_KEY
#       2 from scrapers import EbayScraper
# ----> 4 results = EbayScraper(SERB_API_KEY).scrape(product)
#       6 results
#
# File ~/Desktop/data-aquisiotion-project/scraping_service/scrapers/ebay.py:20, in EbayScraper.scrape(self, product_name)
#      18 self._parse_api_response()
#      19 for listing in self._parsed_results:
# ---> 20     self._push_to_list.push(listing)
#      21 return self._parsed_results
#
# AttributeError: 'NoneType' object has no attribute 'push'

# %%
from scrapers import JumiaScraper

JumiaScraper().scrape(product)

# %%
from scrapers import NoonScraper
from pandas import DataFrame
from scrapers.read_once_list import ReadOnceList

listings = ReadOnceList()

scraper = NoonScraper()
scraper.push_to(listings)
scraper.scrape(product)

DataFrame(
    [listing.to_json() for listing in listings.read()],
)
# Out:
# Exception in thread Thread-7 (start):
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/web_driver_management.py", line 46, in start
#     result = task.execute(self._driver)
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/web_driver_management.py", line 21, in execute
#     return self._func(driver)
#            ~~~~~~~~~~^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 36, in <lambda>
#     WebDriverTask(url, lambda drv: _ListingLinkScraper(drv).scrape())
#                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 93, in scrape
#     self._construct_listing()
#     ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 98, in _construct_listing
#     name=self.title,
#          ^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 78, in wrapper
#     return func(self)
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 113, in title
#     title_element = self._driver.find_element(By.TAG_NAME, "h1")
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py", line 816, in find_element
#     return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py", line 446, in execute
#     self.error_handler.check_response(response)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/errorhandler.py", line 232, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.InvalidSessionIdException: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# #0 0x559b952c240a <unknown>
# #1 0x559b94cf6598 <unknown>
# #2 0x559b94d3a3ad <unknown>
# #3 0x559b94d3b461 <unknown>
# #4 0x559b9528adf9 <unknown>
# #5 0x559b9528dd5d <unknown>
# #6 0x559b95273b41 <unknown>
# #7 0x559b9528e93b <unknown>
# #8 0x559b9525a870 <unknown>
# #9 0x559b952af828 <unknown>
# #10 0x559b952af9fc <unknown>
# #11 0x559b952c1763 <unknown>
# #12 0x7acff0ca3d64 <unknown>
# #13 0x7acff0d373fc <unknown>
#
# Exception in thread Thread-8 (start):
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/web_driver_management.py", line 46, in start
#     result = task.execute(self._driver)
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/web_driver_management.py", line 21, in execute
#     return self._func(driver)
#            ~~~~~~~~~~^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 36, in <lambda>
#     WebDriverTask(url, lambda drv: _ListingLinkScraper(drv).scrape())
#                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 93, in scrape
#     self._construct_listing()
#     ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 105, in _construct_listing
#     subvendor=self.subvendor,
#               ^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 78, in wrapper
#     return func(self)
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 155, in subvendor
#     subvendor_element = self._driver.find_element(
#         By.CLASS_NAME, "PartnerRatingsV2-module-scss-module__1CV-Aa__soldBy"
#     )
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py", line 816, in find_element
#     return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py", line 446, in execute
#     self.error_handler.check_response(response)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/errorhandler.py", line 232, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.InvalidSessionIdException: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# #0 0x623dafcfb40a <unknown>
# #1 0x623daf72f598 <unknown>
# #2 0x623daf7733ad <unknown>
# #3 0x623daf774461 <unknown>
# #4 0x623dafcc3df9 <unknown>
# #5 0x623dafcc6d5d <unknown>
# #6 0x623dafcacb41 <unknown>
# #7 0x623dafcc793b <unknown>
# #8 0x623dafc93870 <unknown>
# #9 0x623dafce8828 <unknown>
# #10 0x623dafce89fc <unknown>
# #11 0x623dafcfa763 <unknown>
# #12 0x7e569d2a3d64 <unknown>
# #13 0x7e569d3373fc <unknown>
# Empty DataFrame
# Columns: []
# Index: []
# Exception in thread Thread-9 (start):
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/web_driver_management.py", line 46, in start
#     result = task.execute(self._driver)
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/web_driver_management.py", line 21, in execute
#     return self._func(driver)
#            ~~~~~~~~~~^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 36, in <lambda>
#     WebDriverTask(url, lambda drv: _ListingLinkScraper(drv).scrape())
#                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 93, in scrape
#     self._construct_listing()
#     ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 105, in _construct_listing
#     subvendor=self.subvendor,
#               ^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 78, in wrapper
#     return func(self)
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/scrapers/noon.py", line 158, in subvendor
#     return subvendor_element.text
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webelement.py", line 105, in text
#     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webelement.py", line 508, in _execute
#     return self._parent.execute(command, params)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py", line 446, in execute
#     self.error_handler.check_response(response)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/mohsen/Desktop/data-aquisiotion-project/scraping_service/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/errorhandler.py", line 232, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.InvalidSessionIdException: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# #0 0x63dd19d3640a <unknown>
# #1 0x63dd1976a598 <unknown>
# #2 0x63dd197ae3ad <unknown>
# #3 0x63dd197af461 <unknown>
# #4 0x63dd19cfedf9 <unknown>
# #5 0x63dd19d01d5d <unknown>
# #6 0x63dd19ce7b41 <unknown>
# #7 0x63dd19d0293b <unknown>
# #8 0x63dd19cce870 <unknown>
# #9 0x63dd19d23828 <unknown>
# #10 0x63dd19d239fc <unknown>
# #11 0x63dd19d35763 <unknown>
# #12 0x7278eeea3d64 <unknown>
# #13 0x7278eef373fc <unknown>
